# %%
import numpy as np
import pandas as pd
import proque_stat

# %%
crp = proque_stat.PyBatchCRP(0.001, 100, np.array([1.0, 1.0]))

# %%
crp.seat(np.array([1.0, 2.0]))
# crp.seat(np.array([1.0, 2.0]))
# crp.seat(np.array([20.0, 60.0]))
df = pd.DataFrame(columns=['x', 'y'], data = [crp.draw() for i in range(100)])
# Out:
# TBLE_PP: 0.001
# TBL_COUNT: 0
# Seating at 943db53e-ff0b-467f-ab90-f58ebe668ede
# SAMPLES: [[1, 2]]
# SAMPLE MEAN: [1, 2]
# NEW MEAN [1, 2]
# DEVIATIONS: [[0, 0]]
# OLD PSI: [[1, 0],
#  [0, 1]]
# NEW C: [[0, 0],
#  [0, 0]]
# mean_adj_coeff: 0
# mean_psi_adj: 0
# NEW PSI: [[1, 0],
#  [0, 1]]
# SIG K0: 1
# SIG PSI: [[1, 0],
#  [0, 1]]
# SIG COEFF: inf
# SCALED SIG: [[1, 0],
#  [0, 1]]
# CLIPPED SCALED SIG: [[1, 0],
#  [0, 1]]
# Z: [0.8885457922031185, -1.797433399326491]
# J SCALED SIG: [[1, 0],
#  [0, 1]]
# ROOT: [[1, 0],
#  [0, 1]]
# RESULT: [1.8885457922031184, 0.20256660067350896]
# SIG K0: 1
# SIG PSI: [[1, 0],
#  [0, 1]]
# SIG COEFF: inf
# SCALED SIG: [[1, 0],
#  [0, 1]]
# CLIPPED SCALED SIG: [[1, 0],
#  [0, 1]]
# Z: [-0.8006912117444019, -0.5574653990632137]
# J SCALED SIG: [[1, 0],
#  [0, 1]]
# ROOT: [[1, 0],
#  [0, 1]]
# RESULT: [0.19930878825559806, 1.4425346009367863]
# SIG K0: 1
# SIG PSI: [[1, 0],
#  [0, 1]]
# SIG COEFF: inf
# SCALED SIG: [[1, 0],
#  [0, 1]]
# ...

# %%
crp.draw()
# Out:
# SIG K0: 1
# SIG PSI: [[1, 0],
#  [0, 1]]
# SIG COEFF: inf
# SCALED SIG: [[1, 0],
#  [0, 1]]
# CLIPPED SCALED SIG: [[1, 0],
#  [0, 1]]
# Z: [0.14860348631139023, -1.8150538182408442]
# J SCALED SIG: [[1, 0],
#  [0, 1]]
# ROOT: [[1, 0],
#  [0, 1]]
# RESULT: [1.1486034863113903, 0.18494618175915578]
# array([1.14860349, 0.18494618])

# %%
df.mean()
# Out:
# x    0.922734
# y    1.956746
# dtype: float64

# %%
crp.draw()

# %%
df.hist()
