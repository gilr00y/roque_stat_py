# %%
import numpy as np
import pandas as pd
import proque_stat

# %%
crp = proque_stat.PyBatchCRP(0.001, 100, np.array([1.0, 1.0]))

# %%
crp.seat(np.array([1.0, 2.0]))
# Out:
# TBLE_PP: 0.001
# TBL_COUNT: 0
# TBL COUNT IS 0, so PP is being set to 1
# COunt = 0, ALpha: 0.001, Sum_pp: 0.001
# NORMALIZED_PP: 1
# TABLE ID: 2f09ce3c-f315-49d4-9e18-93a429f908bd
# SELECT: 0.4445740923208126
# max thresh: 1
# Seating at 2f09ce3c-f315-49d4-9e18-93a429f908bd

# %%
results = [crp.draw() for i in range(500)]
# Out:
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5

# %%
results[1]
# Out:
# array([2.30944262, 1.76981421])

# %%
results[0]
# Out:
# array([3.22635691, 2.0754523 ])

# %%
crp.seat(np.array([20.0, 60.0]))
df = pd.DataFrame(columns=['x', 'y'], data = [crp.draw() for i in range(500)])
# Out:
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# X: [20, 60] | MU: [1.5, 1.5]
# SIG: [[2.25, 0.75],
#  [0.75, 2.25]]
# DEVIATION: [18.5, 58.5]
# PROJ: 1521.5
# COEFF: 0.1193662073189215
# SIG DET: 4.5
# SIG DET INV SQRT: 0.47140452079103173
# THE REST: 0.000000018027825183466957
# TBLE_PP: 0.0000000010144215723439549
# TBL_COUNT: 1
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# X: [20, 60] | MU: [12.5, 12.5]
# SIG: [[2.25, 0.75],
#  [0.75, 2.25]]
# DEVIATION: [7.5, 47.5]
# PROJ: 1037.5
# COEFF: 0.1193662073189215
# SIG DET: 4.5
# SIG DET INV SQRT: 0.47140452079103173
# THE REST: 0.00000005665029178954861
# TBLE_PP: 0.0000000031876988758244725
# TBL_COUNT: 1
# TBLE_PP: 0.001
# TBL_COUNT: 0
# TBL COUNT NOT 0, SO PP CALCULATED as 0.000001014417309640235
# COunt = 0, ALpha: 0.001, Sum_pp: 0.0010000042021204483
# NORMALIZED_PP: 0.000001014417309640235
# TBL COUNT NOT 0, SO PP CALCULATED as 0.000003187685480786131
# COunt = 0, ALpha: 0.001, Sum_pp: 0.0010000042021204483
# NORMALIZED_PP: 0.000003187685480786131
# TBL COUNT IS 0, so PP is being set to 0.9999957978972095
# COunt = 0, ALpha: 0.001, Sum_pp: 0.0010000042021204483
# NORMALIZED_PP: 0.9999957978972095
# TABLE ID: 2f09ce3c-f315-49d4-9e18-93a429f908bd
# SELECT: 0.16838841165448115
# max thresh: 0.000001014417309640235
# TABLE ID: 5b559271-3104-4ef0-b65e-f0aa5bda5356
# SELECT: 0.16838841165448115
# max thresh: 0.000004202102790426366
# TABLE ID: fb786d1a-9a40-4a6f-8db7-65c8f968790e
# SELECT: 0.16838841165448115
# max thresh: 0.9999999999999999
# Seating at fb786d1a-9a40-4a6f-8db7-65c8f968790e
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[1.5, 0.5],
#  [0.5, 1.5]]
# SIG COEFF: 1.5
# SIG K0: 2
# SIG PSI: [[801, 800],
#  [800, 801]]
# SIG COEFF: 1.5

# %%
crp.draw
