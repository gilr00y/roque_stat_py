# %%
import numpy as np
import pandas as pd
import proque_stat

# %%
crp = proque_stat.Roque(0.001, 100, np.array([2.0, 2.0]))

# %%
crp.seat(np.array([3.50, 2.0]))
crp.seat(np.array([20.0, 60.0]))
df = pd.DataFrame(columns=['x', 'y'], data = [crp.draw() for i in range(100)])
# Out:
# TBLE_PP: 0.001
# TBL_COUNT: 0
# Seating at bd07d2f6-b42f-4bba-bd4d-67ccf6999012
# SAMPLES: [[3.5, 2]]
# SAMPLE MEAN: [3.5, 2]
# NEW MEAN [3.5, 2]
# DEVIATIONS: [[0, 0]]
# OLD PSI: [[2, 0],
#  [0, 2]]
# NEW C: [[0, 0],
#  [0, 0]]
# mean_adj_coeff: 0
# mean_psi_adj: 0
# NEW PSI: [[2, 0],
#  [0, 2]]
# SIG K0: 1
# SIG PSI: [[2, 0],
#  [0, 2]]
# X: [20, 60] | MU: [3.5, 2]
# SIG: [[2, 0],
#  [0, 2]]
# DEVIATION: [16.5, 58]
# PROJ: 1818.125
# COEFF: 0.1193662073189215
# SIG DET: 4
# SIG DET INV SQRT: 0.5
# THE REST: 0.000000010579020863066576
# TBLE_PP: 0.0000000006313887987860004
# TBL_COUNT: 1
# TBLE_PP: 0.001
# TBL_COUNT: 0
# Seating at 4c6f8fd2-4b60-4d2e-9a49-0a3dbb09e5e5
# SAMPLES: [[20, 60]]
# SAMPLE MEAN: [20, 60]
# NEW MEAN [20, 60]
# DEVIATIONS: [[0, 0]]
# OLD PSI: [[2, 0],
#  [0, 2]]
# NEW C: [[0, 0],
#  [0, 0]]
# mean_adj_coeff: 0
# mean_psi_adj: 0
# NEW PSI: [[2, 0],
#  [0, 2]]
# SIG K0: 1
# SIG PSI: [[2, 0],
#  [0, 2]]
# SCALED SIG: [[2, 0],
#  [0, 2]]
# ...

# %%
crp.draw()
# Out:
# 3849054262]
# SIG K0: 1
# SIG PSI: [[2, 0],
#  [0, 2]]
# SCALED SIG: [[2, 0],
#  [0, 2]]
# CLIPPED SCALED SIG: [[2, 0],
#  [0, 2]]
# Z: [1.0996268159701899, -1.4755627864087197]
# J SCALED SIG: [[1.4142135623730951, 0],
#  [0, 1.4142135623730951]]
# ROOT: [[1.4142135623730951, 0],
#  [0, 1.4142135623730951]]
# RESULT: [21.555107156694184, 57.913239095327754]
# SIG K0: 1
# SIG PSI: [[2, 0],
#  [0, 2]]
# SCALED SIG: [[2, 0],
#  [0, 2]]
# CLIPPED SCALED SIG: [[2, 0],
#  [0, 2]]
# Z: [-0.6222193027804505, -1.1592983076547994]
# J SCALED SIG: [[1.4142135623730951, 0],
#  [0, 1.4142135623730951]]
# ROOT: [[1.4142135623730951, 0],
#  [0, 1.4142135623730951]]
# RESULT: [19.120049023237556, 58.36050461047841]
# SIG K0: 1
# SIG PSI: [[2, 0],
#  [0, 2]]
# SCALED SIG: [[2, 0],
#  [0, 2]]
# CLIPPED SCALED SIG: [[2, 0],
#  [0, 2]]
# Z: [-0.37524251794038943, 0.7370738582216485]
# J SCALED SIG: [[1.4142135623730951, 0],
#  [0, 1.4142135623730951]]
# ROOT: [[1.4142135623730951, 0],
# ...

# %%
df.mean()
# Out:
# ]
# SCALED SIG: [[2, 0],
#  [0, 2]]
# CLIPPED SCALED SIG: [[2, 0],
#  [0, 2]]
# Z: [-0.8012025022593947, 0.44215481132740486]
# J SCALED SIG: [[1.4142135623730951, 0],
#  [0, 1.4142135623730951]]
# ROOT: [[1.4142135623730951, 0],
#  [0, 1.4142135623730951]]
# RESULT: [2.3669285550975037, 2.625301330847733]
# SIG K0: 1
# SIG PSI: [[2, 0],
#  [0, 2]]
# SCALED SIG: [[2, 0],
#  [0, 2]]
# CLIPPED SCALED SIG: [[2, 0],
#  [0, 2]]
# Z: [-0.3673228457565267, -0.7343077024069934]
# J SCALED SIG: [[1.4142135623730951, 0],
#  [0, 1.4142135623730951]]
# ROOT: [[1.4142135623730951, 0],
#  [0, 1.4142135623730951]]
# RESULT: [2.9805270497616396, 0.9615320883010032]
# SIG K0: 1
# SIG PSI: [[2, 0],
#  [0, 2]]
# SCALED SIG: [[2, 0],
#  [0, 2]]
# CLIPPED SCALED SIG: [[2, 0],
#  [0, 2]]
# Z: [1.1226657919652983, 0.9181631864003689]
# J SCALED SIG: [[1.4142135623730951, 0],
#  [0, 1.4142135623730951]]
# ROOT: [[1.4142135623730951, 0],
#  [0, 1.4142135623730951]]
# ...

# %%
proj_crp = crp.project(np.array([0]))

# %%
df = pd.DataFrame(columns=['x'], data = [proj_proj_crp.draw()
# Out:
# SIG K0: 1
# SIG PSI: [[2]]
# SCALED SIG: [[4]]
# CLIPPED SCALED SIG: [[4]]
# Z: [0.7960212123067761]
# J SCALED SIG: [[2]]
# ROOT: [[2]]
# RESULT: [21.592042424613552]
# array([21.59204242])

# %%
df.hist()
# Out:
# 8]
# J SCALED SIG: [[1.4142135623730951, 0],
#  [0, 1.4142135623730951]]
# ROOT: [[1.4142135623730951, 0],
#  [0, 1.4142135623730951]]
# RESULT: [2.2252178456844036, 2.3275066564521496]
# SIG K0: 1
# SIG PSI: [[2, 0],
#  [0, 2]]
# SCALED SIG: [[2, 0],
#  [0, 2]]
# CLIPPED SCALED SIG: [[2, 0],
#  [0, 2]]
# Z: [0.06363298055438146, -0.6393958282616679]
# J SCALED SIG: [[1.4142135623730951, 0],
#  [0, 1.4142135623730951]]
# ROOT: [[1.4142135623730951, 0],
#  [0, 1.4142135623730951]]
# RESULT: [20.08999062411423, 59.09575774794757]
# SIG K0: 1
# SIG PSI: [[2, 0],
#  [0, 2]]
# SCALED SIG: [[2, 0],
#  [0, 2]]
# CLIPPED SCALED SIG: [[2, 0],
#  [0, 2]]
# Z: [-0.03199406830069377, 0.06031145476326778]
# J SCALED SIG: [[1.4142135623730951, 0],
#  [0, 1.4142135623730951]]
# ROOT: [[1.4142135623730951, 0],
#  [0, 1.4142135623730951]]
# RESULT: [3.4547535546936676, 2.085293277292665]
# SIG K0: 1
# SIG PSI: [[2, 0],
#  [0, 2]]
# SCALED SIG: [[2, 0],
#  [0, 2]]
# CLIPPED SCALED SIG: [[2, 0],
# ...
